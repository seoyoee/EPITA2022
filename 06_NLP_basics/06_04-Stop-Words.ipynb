# %% [markdown]
# # Stop Words
# Words like "a" and "the" appear so frequently that they don't require tagging as thoroughly as nouns, verbs and modifiers. We call these *stop words*, and they can be filtered from the text to be processed. spaCy holds a built-in list of some 305 English stop words.

# %%
# Perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Print the set of spaCy's default stop words (remember that sets are unordered):
print(nlp.Defaults.stop_words)
# Out:
# {'yet', 'among', 'amongst', 'least', 'this', 'hereafter', '’d', 'n‘t', 'when', 'see', 'from', 'or', 'ours', 'thereafter', 'onto', 'you', 'more', 'many', 'she', 'too', 'beyond', 'has', 'forty', 'everything', 'somewhere', '‘re', 'nowhere', 'ourselves', 'thereupon', 'still', 'neither', 'where', 'cannot', 'again', 'move', 'anywhere', 'him', 'any', 'it', 'not', 'front', 'few', 'if', 'either', '‘m', 'also', 'her', 'after', 'became', 'otherwise', 'well', 'together', 'yours', 'made', 'less', 'over', 'wherein', 'a', 'toward', 'do', 'on', 'were', 'he', 'however', 'am', 'below', 'how', 'whereupon', 'hereby', '’ll', 'mine', 'sometimes', 'wherever', 'whence', 'seeming', 'n’t', 'towards', 'others', "'s", 'empty', 'something', 'rather', 'please', 'just', 'nevertheless', 'done', 'an', '‘ll', 'quite', 'afterwards', '’s', '’re', 'almost', 'had', 'up', 'last', 'sixty', 'everyone', 'so', 'four', "'re", 'name', 'why', 'himself', 'via', 'between', 'unless', 'throughout', '’m', 'former', 'namely', 'behind', "'ve", 'of', 'nor', 'them', 'every', 'whereas', 'within', 'through', 'while', 'should', 'as', 'next', 'i', 'moreover', 'those', 'first', 'noone', 'to', '‘s', 'two', 'their', 'eleven', 'five', 'get', 'whether', 'about', 'its', 'ever', 'seemed', 'therein', 'will', 'against', 'your', 'formerly', 'thence', 'upon', 'yourselves', 'are', 'must', 'beforehand', 'beside', 'can', 'hers', 'before', 'already', 'own', 'would', 'but', 'these', 'did', 'than', 'thru', 'say', 'three', 'which', 'twenty', 'being', '‘d', 'serious', 'several', 'take', 'none', 'my', 'whom', 'nothing', 'bottom', 'each', 'us', 'nine', 'never', 'down', 'often', 'once', 'whoever', 'most', 'our', 'with', 'whenever', 'at', 'be', 'make', 'out', 'hundred', 'we', 'around', 'ca', 'themselves', 'then', 'fifty', 'six', 'very', 'top', 'whole', 'no', 'may', 'was', 'is', 'latter', 'becoming', 'could', 'in', 'else', 'same', 'only', 'somehow', 'such', 'what', 'along', 'does', 'by', 'who', 'hereupon', '‘ve', 'twelve', 'really', 'thereby', 'without', 'part', 'enough', 'put', 'therefore', 'alone', 'seem', 'side', 'always', 'under', 'now', 'give', 'during', 'anyway', 'using', 'herein', 'his', 'seems', 'anyhow', 'myself', 'there', 'because', 'into', 'mostly', 'meanwhile', 'me', 'the', "'d", 're', 'thus', 'ten', 'amount', 'across', 'although', 'show', 'due', 'regarding', 'further', 'yourself', 'above', 'except', 'that', 'off', 'doing', 'various', 'here', 'eight', 'someone', 'become', 'whatever', 'third', 'have', 'whither', 'whose', 'since', 'besides', 'keep', 'call', 'even', 'latterly', 'both', 'all', 'been', 'other', '’ve', 'herself', 'anything', 'go', 'another', 'much', "n't", 'though', 'becomes', 'and', 'they', 'until', 'hence', 'nobody', 'might', 'one', 'back', 'everywhere', 'whereafter', 'perhaps', 'itself', 'anyone', 'some', 'sometime', 'used', 'elsewhere', 'for', 'fifteen', 'indeed', 'full', "'m", 'whereby', "'ll", 'per'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %% [markdown]
# ## To see if a word is a stop word

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %% [markdown]
# ## To add a stop word
# There may be times when you wish to add a stop word to the default set. Perhaps you decide that `'btw'` (common shorthand for "by the way") should be considered a stop word.

# %%
# Add the word to the set of stop words. Use lowercase!
nlp.Defaults.stop_words.add('btw')

# Set the stop_word tag on the lexeme
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %% [markdown]
# <font color=green>When adding stop words, always use lowercase. Lexemes are converted to lowercase before being added to **vocab**.</font>

# %% [markdown]
# ## To remove a stop word
# Alternatively, you may decide that `'beyond'` should not be considered a stop word.

# %%
# Remove the word from the set of stop words
nlp.Defaults.stop_words.remove('beyond')

# Remove the stop_word tag from the lexeme
nlp.vocab['beyond'].is_stop = False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False
