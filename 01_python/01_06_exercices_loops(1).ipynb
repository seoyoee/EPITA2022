# %% [markdown]
# # Python Cours : Exercices 2

# %% [markdown]
# ## Loops
#
# ### Exercice 12 :
#  - 1) Write a program that uses a `while' loop to add the squares of integers (starting from 1) until the total exceeds 200. Display the final total and the last number to be squared and added.

# %% [markdown]
# ### Exercice 13 :
#
# - 1) Create a tuple of month names and a tuple of the number of days in each month (assume February has 28 days). Using a single `for` loop, construct a dictionary that has the month names as keys and the corresponding day numbers as values.
# - 2) Now do the same thing without using a `for` loop.

# %% [markdown]
# ### Exercice 14
#
# person = {}
# ```
# for prop in ["name", "surname", "age", "height", "weight"]:
#     person[prop] = input("Please enter your %s: " % prop)
# ```
#
#  - Modify the above example to include the type conversion of the properties: age should be an integer, height and weight should be floats, and first and last name should be strings.

# %% [markdown]
# ### Exercice 15: Count the total number of digits in a number
#
# Write a program to count the total number of digits in a number using a while loop.
#
# For example, the number is 75869, so the output should be 5.

# %% [markdown]
# ###Exercise 16: Write a program to display all prime numbers within a range
#
# Note: A Prime Number is a number that cannot be made by multiplying other whole numbers. A prime number is a natural number greater than 1 that is not a product of two smaller natural numbers
#
# Examples:
#
#     6 is not a prime mumber because it can be made by 2×3 = 6
#     37 is a prime number because no other whole numbers multiply together to make it.
#
# Given:
#
#     # range
#     start = 25
#     end = 50
#
# Expected output:
#
#     Prime numbers between 25 and 50 are:
#     29
#     31
#     37
#     41
#     43
#     47

# %% [markdown]
# ###Exercise 17: Reverse a given integer number
#
# Given:
#
#     76542
#
# Expected output:
#
#     24567
